# %%
customer_name ="Rajukumar"
age = int("40")
account_number = 123456789
is_account_active = True
monthly_salary = 3000000
is_guarantor_available = True
good_credit = True
print ("*********Customer Application Status*********")
if 21 <= age < 60 and monthly_salary >= 30000 and is_account_active ==True and is_guarantor_available == True and good_credit == True:
    print(f"Congratulations! Your application has been approved, {customer_name}")
else:
   print("Sorry! Your application has been rejected")
# Out:
# *********Customer Application Status*********
# Congratulations! Your application has been approved, RAjukumar
