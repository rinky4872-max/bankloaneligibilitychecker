# %%
first_name = "Anita"
last_name = "Rao"
age = 28
department = "Artificial Intelligence"
salary = 65000.50
is_active = True
full_name = f"{first_name} {last_name}"
print("----- EMPLOYEE PROFILE -----")
print(f"Name: {full_name}")
print(f"Name length: {len(full_name)}")
print(f"Age: {age}")
print(f"Department: {department}")
print(f"Salary: ₹{salary}")
print(f"Active employee: {is_active}")
annual_salary = 780000
monthly_salary = annual_salary / 12
review_threshold = 70000

employee_name = "Anita Rao"
is_active = True

eligible_for_review = monthly_salary < review_threshold and is_active

print("----- SALARY REVIEW -----")
print(f"Employee: {employee_name}")
print(f"Monthly salary: ₹{monthly_salary:.2f}")
print(f"Eligible for review: {eligible_for_review}")
# Out:
# ----- EMPLOYEE PROFILE -----
# Name: Anita Rao
# Name length: 9
# Age: 28
# Department: Artificial Intelligence
# Salary: ₹65000.5
# Active employee: True
# ----- SALARY REVIEW -----
# Employee: Anita Rao
# Monthly salary: ₹65000.00
# Eligible for review: True
