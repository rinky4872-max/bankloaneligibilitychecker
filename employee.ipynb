# %%
first_name = "RAJUKUMAR"
last_name = "SRIPELLI"
age = 30
Total_ctc = 600000
monthly_salary = Total_ctc/12
elegible_for_bonus = True
review_threshold = 70000
elegible_for_review = True
full_name = f"{first_name} {last_name}"
is_active = True
print("----Employee details----")
print(f"Name: {full_name}")
print(f"Age: {age}")
print(f"Total CTC: {Total_ctc:.2f}")
print(f"Monthly Salary: {monthly_salary:.2f}")
print(f"Active employee: {is_active}")
eligible_for_review = monthly_salary < review_threshold and is_active
print(f"Eligible for Bonus: {elegible_for_bonus}")
print(f"Eligible for Performance Review: {eligible_for_review}")
# Out:
# ----Employee details----
# Name: RAJUKUMAR SRIPELLI
# Age: 30
# Total CTC: 600000.00
# Monthly Salary: 50000.00
# Active employee: True
# Eligible for Bonus: True
# Eligible for Performance Review: True
