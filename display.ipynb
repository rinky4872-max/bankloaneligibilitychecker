# %%
first_name = "Rajukumar"
last_name = "Sripelli"
course = "Electrical Programming"
age = 40
Eligible_age = age >= 40
course_fee = 20000.75
is_fee_paid = True
Full_name = f"first_name {first_name} last_name {last_name}"
print(len(course))
print(f"Course Fee: ${course_fee:.2f}")
print(f"Age: {age}")
print(course.upper())
print(course.lower())
print("\n")
print (f"Eligible for course: {Eligible_age}, Fee Paid: {is_fee_paid}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Project\.venv-1\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:1429, in PyDB.apply_files_filter(self, frame, original_filename, force_check_project_scope)
#    1428 try:
# -> 1429     return self._apply_filter_cache[cache_key]
#    1430 except KeyError:
#
# KeyError: (184, 'c:\\Users\\Cherry\\Documents\\Project\\.venv-1\\Lib\\site-packages\\IPython\\core\\compilerop.py', True, <code object extra_flags at 0x000001EA27E388F0, file "c:\Users\Cherry\Documents\Project\.venv-1\Lib\site-packages\IPython\core\compilerop.py", line 184>)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
first_name = "Rajukumar"
last_name = "Sripelli"
course = "Electrical Programming"
age = 40
Eligible_age = age >= 40
course_fee = 20000.75
is_fee_paid = True
Full_name = f"first_name {first_name} last_name {last_name}"
print(len(course))
print(f"Course Fee: ${course_fee:.2f}")
print(f"Age: {age}")
print(course.upper())
print(course.lower())
print("\n")
print (f"Eligible for course: {Eligible_age}, Fee Paid: {is_fee_paid}")
