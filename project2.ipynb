# %%
employee_name = "Rajukumar s"
age_text = "40"
annual_salary = "1000000"
is_active = True
good_credit =True
age = int (age_text)
employee_name =employee_name.strip().title()

def calculate_monthly_salary(annual_salary):
    return int(annual_salary) / 12

monthly_salary = calculate_monthly_salary(annual_salary)

if 18 <= age < 65 and is_active:
    employment_status = "Eligible working age"
else:
    employment_status = "Not eligible working age"

if monthly_salary >= 60000 and good_credit:
    benefit_status = "Eligible for premium benefit"
else:
    benefit_status = "Not eligible for premium benefit"

print("----- EMPLOYEE REPORT -----")
print(f"Name: {employee_name}")
print(f"Name length: {len(employee_name)}")
print(f"Age: {age}")
print(f"Monthly salary: ₹{monthly_salary:.2f}")
print(f"Employment status: {employment_status}")
print(f"Benefit status: {benefit_status}")

print("\nReview attempts:")

for attempt in range(3):
    print(f"Attempt {attempt + 1}: Checked")
# Out:
# ----- EMPLOYEE REPORT -----
# Name: Rajukumar S
# Name length: 11
# Age: 40
# Monthly salary: ₹83333.33
# Employment status: Eligible working age
# Benefit status: Eligible for premium benefit
#
# Review attempts:
# Attempt 1: Checked
# Attempt 2: Checked
# Attempt 3: Checked
