# %%
first_name = "Rajukumar"
last_name = "Sripelli"
course = "Electrical Programming Language"
age = int(25)
is_fee_paid = True
if 18 <= age <=60 and is_fee_paid == True:
         candidate_status = "Candidate_Eligible"
else:
         candidate_status = "Candidate_Not_Eligible"
course_fee = 20000.75
Full_name = f"{first_name} {last_name}"
print(f"Candidate Full Name: {first_name} {last_name}")
print(len(course))
print(f"Course Fee: ${course_fee:.2f}")
print(f"Age: {age}")
print(course.upper())
print(course.lower())
print("\n")
print(f"Status: {candidate_status}")
# Out:
# Candidate Full Name: Rajukumar Sripelli
# 31
# Course Fee: $20000.75
# Age: 25
# ELECTRICAL PROGRAMMING LANGUAGE
# electrical programming language
#
#
# Status: Candidate_Eligible
